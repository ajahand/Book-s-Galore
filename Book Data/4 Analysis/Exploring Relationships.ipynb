# %% [markdown]
# # 6.2 Exploring relationships

# %% [markdown]
# #  This script contains the following:
# 1. Importing Visualization Libraries and Data
# 2. Data Cleaning
# 3. Exploring Relationships
#  Correlations
#  Scatterplots
#  Pair Plots
#  Categorical Plots

# %% [markdown]
# # 1. Importing Visualization Libraries and Data¶

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
matplotlib.__version__
# Out:
# '3.7.2'

# %%
# %matplotlib inline

# %%
path = r'/Users/ajahanderson/Documents/Book Data'

# %%
df = pd.read_csv(os.path.join(path,'2 Data','Prepared Data','book_dataset_cleaned.csv'),index_col = False)

# %% [markdown]
# ## Checking the data

# %%
df
# Out:
#       Unnamed: 0    ID        Date      Time  Qtr  Special Day  \
# 0              0     1  2018-01-01  08:57:00    1            1
# 1              1     2  2018-01-02  02:04:00    1            1
# 2              2     3  2018-01-03  05:08:00    1            1
# 3              3     4  2018-01-04  16:06:00    1            0
# 4              4     5  2018-01-04  20:12:00    1            0
# ...          ...   ...         ...       ...  ...          ...
# 3475        3475  3476  2019-12-31  12:02:00    4            1
# 3476        3476  3477  2019-12-31  02:53:00    4            1
# 3477        3477  3478  2019-12-31  06:02:00    4            1
# 3478        3478  3479  2019-12-31  07:28:00    4            1
# 3479        3479  3480  2019-12-31  09:06:00    4            1
#
#       Online Sale Offers  Day of week Gender Customer ID  ...       Ship-City  \
# 0                      1            1      F   B07FWXWZT  ...       Hyderabad
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Date', 'Time', 'Qtr', 'Special Day',
#        'Online Sale Offers', 'Day of week', 'Gender', 'Customer ID',
#        'Product-Name', 'Item-Status', 'Quantity', 'Item Price',
#        'Shipping-Price', 'Ship-City', 'Ship-State', 'Ship-Postal-Code',
#        'Category', 'Total', 'Author', 'Publication', 'Profit %',
#        'Profit (INR)', 'Cost Price'],
#       dtype='object')

# %%
sub = df[['Qtr', 'Special Day','Online Sale Offers', 'Day of week', 'Quantity', 'Item Price',
       'Shipping-Price', 'Ship-Postal-Code',
     'Total', 'Profit %',
       'Profit (INR)', 'Cost Price']]

# %% [markdown]
# ## Correlations:

# %%
pd.set_option('display.float_format',lambda x:'%.1f'%x)

# %%
sub.corr()
# Out:
#                     Qtr  Special Day  Online Sale Offers  Day of week  \
# Qtr                 1.0          0.0                -0.0          0.0
# Special Day         0.0          1.0                 0.2         -0.0
# Online Sale Offers -0.0          0.2                 1.0         -0.0
# Day of week         0.0         -0.0                -0.0          1.0
# Quantity            0.0          0.0                 0.0          0.0
# Item Price         -0.1         -0.0                -0.0         -0.0
# Shipping-Price     -0.0          0.0                -0.0          0.0
# Ship-Postal-Code   -0.1         -0.0                 0.0         -0.0
# Total              -0.1         -0.0                -0.0         -0.0
# Profit %            0.1          0.0                -0.0          0.0
# Profit (INR)       -0.1         -0.0                 0.0         -0.0
# Cost Price         -0.1         -0.0                -0.0         -0.0
#
# ...

# %%
f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.
corr = sns.heatmap(sub.corr(), annot = True, ax = ax) # The `annot` argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %% [markdown]
# At first glance, it's evident that the light-colored squares indicate a positive correlation. Many currency-related variables, such as cost prices and profit, are positively linked to other currency values.

# %%
sns.lmplot(x = 'Profit (INR)', y = 'Cost Price', data = df)
# Out:
# /Users/ajahanderson/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
#  The scatterplot displays a positive trend, with an outlier that is noticeable and will be eliminated.

# %%
remove = df[df['Item Price'] > 2000].index

# %%
df.drop(remove, inplace=True)

# %%
sns.lmplot(x = 'Quantity', y = 'Shipping-Price', data = df)
# Out:
# /Users/ajahanderson/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# While it's a positive trend, the points don't align closely with the trend line.

# %%
sns.lmplot(x = 'Profit (INR)', y = 'Item Price', data = df)
# Out:
# /Users/ajahanderson/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sub = ['Quantity', 'Item Price',
       'Shipping-Price','Total', 'Profit %',
       'Profit (INR)', 'Cost Price']
sub_df = df[sub]

# %%
sub_df.head()
# Out:
#    Quantity  Item Price  Shipping-Price  Total  Profit %  Profit (INR)  \
# 0         1       999.0            85.0 1084.0        13         129.9
# 1         1       640.0            85.0  725.0        17         108.8
# 2         1       715.0            85.0  800.0        17         121.5
# 3         1       565.0            85.0  650.0        13          73.5
# 4         1       494.0            85.0  579.0        13          64.2
#
#    Cost Price
# 0       869.1
# 1       531.2
# 2       593.5
# 3       491.6
# 4       429.8

# %%
g = sns.pairplot(sub_df)
# Out:
# /Users/ajahanderson/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ajahanderson/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ajahanderson/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ### Categorical Plots:

# %%
sns.histplot(df['Item Price'], bins = 20, kde = True)
# Out:
# /Users/ajahanderson/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ajahanderson/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Item Price', ylabel='Count'>

# %%
df.loc[df['Item Price'] < 500, 'Price category'] = 'Low price'
# Out:
# /var/folders/5t/s295bnhn7bvf1407s3py_b8h0000gn/T/ipykernel_28509/1042905976.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Low price' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Item Price'] < 500, 'Price category'] = 'Low price'

# %%
df.loc[(df['Item Price'] >= 500) & (df['Item Price'] < 900), 'Price category'] = 'Middle price'

# %%
df.loc[df['Item Price'] >=900 , 'Price category'] = 'High price'

# %%
df['Price category'].value_counts(dropna = False)
# Out:
# Price category
# Low price       2563
# Middle price     696
# High price       217
# Name: count, dtype: int64

# %%
sns.set(style="ticks")
g = sns.catplot(x="Category", y="Item Price", hue="Price category", data=df)
# Out:
# /Users/ajahanderson/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ajahanderson/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ajahanderson/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.set(style="ticks")
g = sns.catplot(x="Cost Price", y="Item Price", hue="Price category", data=df)
# Out:
# /Users/ajahanderson/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ajahanderson/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/ajahanderson/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.set(style="ticks")
g = sns.catplot(x="Category", y="Item Price", hue="Price category", data=df)

# %% [markdown]
# # New Questions

# %% [markdown]
#  1. Why are certain postal codes contribute more orders?
#  2. What's happening in the 2nd quarter?

# %% [markdown]
# # Hypotheses

# %% [markdown]
# 1. There is variability in purchase behavior across different cities or states, impacting the total sales volume.
# 2. There exists a correlation between the cost price of items and the generated profit, influencing profit margins.
# 3. There is a difference in purchasing behavior between genders, reflected in the choice of product categories or authors.
# 4

# %%
df.to_csv(os.path.join(path, '2 Data','Prepared Data', '6.2_task'))
